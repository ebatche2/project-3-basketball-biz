# %%
import pandas as pd
from pathlib import Path

# %%
# Make a reference to the comic_books_expanded.csv file path
csv_path = Path("stadiums.csv")

stadiums_df = pd.read_csv(csv_path, encoding="utf-8")

stadiums_df
# Out:
#                    Team League            Division        Lat        Long
# 0      Dallas Mavericks    NBA                West  32.790556  -96.810278
# 1         Orlando Magic    NBA                East  28.539167  -81.383611
# 2     San Antonio Spurs    NBA                West  29.426944  -98.437500
# 3        Denver Nuggets    NBA                West  39.748920 -105.008400
# 4         Brooklyn Nets    NBA                East  40.682661  -73.975225
# ..                  ...    ...                 ...        ...         ...
# 146     Chicago Fire FC    MLS  Eastern Conference  41.862300  -87.616700
# 147  Philadelphia Union    MLS  Eastern Conference  39.832222  -75.378889
# 148           FC Dallas    MLS  Western Conference  33.154444  -96.835278
# 149       FC Cincinnati    MLS  Eastern Conference  39.111389  -84.522222
# 150    New York City FC    MLS  Eastern Conference  40.829167  -73.926389
#
# [151 rows x 5 columns]

# %%
NBA_stadiums = stadiums_df.loc[stadiums_df["League"] == "NBA"]

NBA_stadiums
# Out:
#                       Team League Division        Lat        Long
# 0         Dallas Mavericks    NBA     West  32.790556  -96.810278
# 1            Orlando Magic    NBA     East  28.539167  -81.383611
# 2        San Antonio Spurs    NBA     West  29.426944  -98.437500
# 3           Denver Nuggets    NBA     West  39.748920 -105.008400
# 4            Brooklyn Nets    NBA     East  40.682661  -73.975225
# 5       Washington Wizards    NBA     East  38.898200  -77.020900
# 6    Golden State Warriors    NBA     West  37.768056 -122.387500
# 7     Los Angeles Clippers    NBA     West  34.043056 -118.267222
# 8       Los Angeles Lakers    NBA     West  34.043056 -118.267222
# 9        Memphis Grizzlies    NBA     West  35.138333  -90.050556
# 10         Milwaukee Bucks    NBA     East  43.045028  -87.918167
# 11            Phoenix Suns    NBA     West  33.445833 -112.071389
# 12              Miami Heat    NBA     East  25.781389  -80.188056
# ...

# %%
NBA_stadiums.to_csv("NBAstadiums.csv",index = False)

# %% [markdown]
# # CONVERT DF TO JSON

# %%
json_data = NBA_stadiums.to_json(orient='records')

# %%
csv_path = Path("teams_info.csv")

teams_df = pd.read_csv(csv_path, encoding="utf-8")

teams_df
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
team_merge = pd.merge(teams_df, ranking_df, on = 'TEAM_ID')

team_merge
# Out:
#         LEAGUE_ID_x     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION  NICKNAME  \
# 0                 0  1610612737      1949      2019          ATL     Hawks
# 1                 0  1610612737      1949      2019          ATL     Hawks
# 2                 0  1610612737      1949      2019          ATL     Hawks
# 3                 0  1610612737      1949      2019          ATL     Hawks
# 4                 0  1610612737      1949      2019          ATL     Hawks
# ...             ...         ...       ...       ...          ...       ...
# 210337            0  1610612744      1946      2019          GSW  Warriors
# 210338            0  1610612744      1946      2019          GSW  Warriors
# 210339            0  1610612744      1946      2019          GSW  Warriors
# 210340            0  1610612744      1946      2019          GSW  Warriors
# 210341            0  1610612744      1946      2019          GSW  Warriors
#
# ...

# %%
csv_path = Path("ranking.csv")

ranking_df = pd.read_csv(csv_path, encoding="utf-8")

ranking_df
# Out:
#            TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE  \
# 0       1610612743          0      22022    2022-12-22       West
# 1       1610612763          0      22022    2022-12-22       West
# 2       1610612740          0      22022    2022-12-22       West
# 3       1610612756          0      22022    2022-12-22       West
# 4       1610612746          0      22022    2022-12-22       West
# ...            ...        ...        ...           ...        ...
# 210337  1610612765          0      22013    2014-09-01       East
# 210338  1610612738          0      22013    2014-09-01       East
# 210339  1610612753          0      22013    2014-09-01       East
# 210340  1610612755          0      22013    2014-09-01       East
# 210341  1610612749          0      22013    2014-09-01       East
#
#                 TEAM   G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0             Denver  30  19  11  0.633        10-3         9-8           NaN
# ...

# %%
from nba_api.stats.static import players
# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_players[:30]
# Out:
# Number of players fetched: 4815
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim',
#   'is_active': False},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy',
#   'is_active': False},
# ...

# %%
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import cumestatsteamgames, cumestatsteam, gamerotation
import pandas as pd
import numpy as np
import json
import difflib
import time
import requests

# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203076   2012-13        00  1610612740               NOH        20.0
# 1      203076   2013-14        00  1610612740               NOP        21.0
# 2      203076   2014-15        00  1610612740               NOP        22.0
# 3      203076   2015-16        00  1610612740               NOP        23.0
# 4      203076   2016-17        00  1610612740               NOP        24.0
# 5      203076   2017-18        00  1610612740               NOP        25.0
# 6      203076   2018-19        00  1610612740               NOP        26.0
# 7      203076   2019-20        00  1610612747               LAL        27.0
# 8      203076   2020-21        00  1610612747               LAL        28.0
# 9      203076   2021-22        00  1610612747               LAL        29.0
# 10     203076   2022-23        00  1610612747               LAL        30.0
#
# ...

# %%
from nba_api.stats.endpoints import TeamYearByYearStats

data = TeamYearByYearStats.TeamYearByYearStats
data.get_data_frames()[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 3
#       1 from nba_api.stats.endpoints import TeamYearByYearStats
# ----> 3 data = TeamYearByYearStats.TeamYearByYearStats
#       4 data.get_data_frames()[0]
#
# AttributeError: type object 'TeamYearByYearStats' has no attribute 'TeamYearByYearStats'

# %%
from nba_api.stats.static import teams
# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
nba_teams[:30]
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...
